# %%
#Table of contents
#This includes making labels and data profiling

# %%
import pandas as pd
import numpy as np
import os

# %%
ords_prods=pd.read_csv(r'/Users/hillelkrief1/Desktop/CareerFoundry/Course 2 Data Immersion/Achievement 4/Instacart Basket Analysis 08-2022/02 Data/Prepared Data/orders_products_merged.csv',index_col=False)

# %%
df = ords_prods[:1000000]

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/xt/zrqk4mvj6cj4y973_7tp2_nw0000gp/T/ipykernel_7938/2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna=False)
# Out:
# Mid-range product    652638
# Low-range product    338018
# High range             9344
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 24.5

# %%
ords_prods.loc[ords_prods['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods.loc[(ords_prods['prices'] <= 15) & (ords_prods['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
ords_prods.loc[ords_prods['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
ords_prods['price_range_loc'].value_counts(dropna=False)
# Out:
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %%
ords_prods['orders_day_of_week'].value_counts(dropna=False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %%
result = []

for value in ords_prods["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
ords_prods['busiest_day']=result

# %%
ords_prods['busiest_day'].value_counts(dropna=False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_day, dtype: int64

# %%
#Here begins the task portion of 4.7

# %%
#Organize a column into the two busiest days and the two slowest days:

# %%
result = []

for value in ords_prods["orders_day_of_week"]:
  if value == [0,1]:
    result.append("Busiest Days")
  elif value == [4,3]:
    result.append("Slowest Days")
  else:
    result.append("Regularly busy")

# %%
result = []

for value in ords_prods["orders_day_of_week"]:
  if value == 0 or value == 1 :
    result.append("Busiest Days")
  elif value == 4 or value==3:
    result.append("Slowest Days")
  else:
    result.append("Regularly busy")

# %%
ords_prods['busiest_day']=result

# %%
ords_prods['busiest_day'].value_counts(dropna=False)
# Out:
# Regularly busy    12916111
# Busiest Days      11864412
# Slowest Days       7624336
# Name: busiest_day, dtype: int64

# %%
ords_prods
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32404854       49688      Fresh Foaming Cleanser        73             11
# 32404855       49688      Fresh Foaming Cleanser        73             11
# 32404856       49688      Fresh Foaming Cleanser        73             11
# 32404857       49688      Fresh Foaming Cleanser        73             11
# 32404858       49688      Fresh Foaming Cleanser        73             11
#
#           prices  Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# ...

# %%
#Checking the busiest hour of the day and making a column based off of it

# %%
ords_prods['order_hour_of_day'].value_counts(dropna=False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %%
result = []

for value in ords_prods["order_hour_of_day"]:
  if value >= 9 and value <= 17 :
    result.append("Most Orders")
  elif value >= 0 and value<=6:
    result.append("Fewest Orders")
  else:
    result.append("Average Orders")

# %%
ords_prods['busiest_period_of_day']=result

# %%
ords_prods['busiest_period_of_day'].value_counts(dropna=False)
# Out:
# Most Orders       23205725
# Average Orders     8312313
# Fewest Orders       886821
# Name: busiest_period_of_day, dtype: int64

# %%
ords_prods.to_pickle(r'/Users/hillelkrief1/Desktop/CareerFoundry/Course 2 Data Immersion/Achievement 4/Instacart Basket Analysis 08-2022/02 Data/Prepared Data/ords_prods_appended.pkl')
